# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
games_df=pd.read_csv(r"C:\Users\PC\Desktop\vgsales.csv")
games_df.head(100)
# Out:
#     Rank                                    Name Platform    Year  \
# 0      1                              Wii Sports      Wii  2006.0
# 1      2                       Super Mario Bros.      NES  1985.0
# 2      3                          Mario Kart Wii      Wii  2008.0
# 3      4                       Wii Sports Resort      Wii  2009.0
# 4      5                Pokemon Red/Pokemon Blue       GB  1996.0
# ..   ...                                     ...      ...     ...
# 95    96  Crash Bandicoot 2: Cortex Strikes Back       PS  1997.0
# 96    97                     Super Mario Bros. 2      NES  1988.0
# 97    98     Super Smash Bros. for Wii U and 3DS      3DS  2014.0
# 98    99              Call of Duty: World at War     X360  2008.0
# 99   100                           Battlefield 3     X360  2011.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                     Nintendo     41.49     29.02      3.77
# ...

# %%
games_df.shape
# Out:
# (16598, 11)

# %%
games_df.set_index("Name", inplace=True)

# %%
columns_list=games_df.columns.tolist()
print(columns_list)
types_list=list(map(type,columns_list))
print(types_list)
# Out:
# ['Rank', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]

# %%
games_df.sort_values(["Global_Sales"], ascending=False,inplace=True)

games_df.head(25)
# Out:
#                                               Rank Platform    Year  \
# Name
# Wii Sports                                       1      Wii  2006.0
# Super Mario Bros.                                2      NES  1985.0
# Mario Kart Wii                                   3      Wii  2008.0
# Wii Sports Resort                                4      Wii  2009.0
# Pokemon Red/Pokemon Blue                         5       GB  1996.0
# Tetris                                           6       GB  1989.0
# New Super Mario Bros.                            7       DS  2006.0
# Wii Play                                         8      Wii  2006.0
# New Super Mario Bros. Wii                        9      Wii  2009.0
# Duck Hunt                                       10      NES  1984.0
# Nintendogs                                      11       DS  2005.0
# Mario Kart DS                                   12       DS  2005.0
# Pokemon Gold/Pokemon Silver                     13       GB  1999.0
# ...

# %%
GTA_V_sales=games_df.loc['Grand Theft Auto V',["Platform","Global_Sales"]]
GTA_V_sales.set_index("Platform",inplace=True)
print(GTA_V_sales)
# Out:
#           Global_Sales
# Platform
# PS3              21.40
# X360             16.38
# PS4              11.98
# XOne              5.08
# PC                1.08

# %%
GTA_df=games_df.loc['Grand Theft Auto V',["Platform","Global_Sales"]]
print(GTA_df)
# Out:
#                    Platform  Global_Sales
# Name
# Grand Theft Auto V      PS3         21.40
# Grand Theft Auto V     X360         16.38
# Grand Theft Auto V      PS4         11.98
# Grand Theft Auto V     XOne          5.08
# Grand Theft Auto V       PC          1.08

# %% [markdown]
# ## GTA 5 global sales

# %%
fig = plt.figure(figsize = (15, 8), dpi = 100)
ax = sns.barplot(x = "Platform", y ="Global_Sales",
data = GTA_df,
palette = "hls")

# %%
GTA_V_sales.plot(kind='bar',color="green", figsize=(10, 6))

plt.xlabel('Platform') 
plt.ylabel('Number of sold games in millions') 
plt.title('Global sales of GTA V in differetent platforms') 
plt.show()

# %%
type(GTA_V_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.barplot(x='Platform', y='Global_Sales', data=GTA_df,palette = "BuGn_r")

# %%
top_5=games_df.head(5)
top_5
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
top_5=games_df.drop(["Genre","Year","Platform","Rank","Publisher","Global_Sales"], axis=1).head(5)
top_5.plot(kind='area',stacked=False,alpha=0.23,figsize=(30, 20),)

plt.title('Top 5 sold games')
plt.ylabel('Total sales')
plt.xlabel('Games titles')

plt.show()

# %%
print(games_df.loc["Wolfenstein: The New Order",["Platform","EU_Sales","JP_Sales"]])
# Out:
#                            Platform  EU_Sales  JP_Sales
# Name
# Wolfenstein: The New Order      PS4      0.80      0.03
# Wolfenstein: The New Order     XOne      0.28      0.00
# Wolfenstein: The New Order      PS3      0.25      0.02
# Wolfenstein: The New Order       PC      0.29      0.00
# Wolfenstein: The New Order     X360      0.19      0.00

# %%
top_PC_10=(games_df["Platform"]=="PC")
games_df[top_PC_10].head(10)
# Out:
#                                         Rank Platform    Year         Genre  \
# Name
# The Sims 3                                84       PC  2009.0    Simulation
# World of Warcraft                        138       PC  2004.0  Role-Playing
# Diablo III                               182       PC  2012.0  Role-Playing
# Microsoft Flight Simulator               195       PC  1996.0    Simulation
# StarCraft II: Wings of Liberty           218       PC  2010.0      Strategy
# Warcraft II: Tides of Darkness           268       PC  1995.0      Strategy
# Half-Life                                282       PC  1997.0       Shooter
# World of Warcraft: The Burning Crusade   289       PC  2007.0  Role-Playing
# The Elder Scrolls V: Skyrim              311       PC  2011.0  Role-Playing
# The Sims: Unleashed                      329       PC  2002.0    Simulation
#
#                                                      Publisher  NA_Sales  \
# Name
# ...

# %%
games_df[(games_df["Platform"]=="PS4")&(games_df["Year"]==2015.0)].head(10)
# Out:
#                                         Rank Platform    Year         Genre  \
# Name
# Call of Duty: Black Ops 3                 34      PS4  2015.0       Shooter
# FIFA 16                                   78      PS4  2015.0        Sports
# Star Wars Battlefront (2015)              93      PS4  2015.0       Shooter
# Fallout 4                                110      PS4  2015.0  Role-Playing
# Uncharted: The Nathan Drake Collection   244      PS4  2015.0        Action
# NBA 2K16                                 315      PS4  2015.0        Sports
# Batman: Arkham Knight                    323      PS4  2015.0        Action
# The Witcher 3: Wild Hunt                 332      PS4  2015.0  Role-Playing
# Metal Gear Solid V: The Phantom Pain     396      PS4  2015.0        Action
# Assassin's Creed Syndicate               410      PS4  2015.0        Action
#
#                                                                      Publisher  \
# Name
# ...

# %%
games_df[(games_df["Platform"]=="PC")&(games_df["Year"]==2015.0)].head(10)
# Out:
#                                   Rank Platform    Year         Genre  \
# Name
# Fallout 4                         1632       PC  2015.0  Role-Playing
# Grand Theft Auto V                1898       PC  2015.0        Action
# The Witcher 3: Wild Hunt          3028       PC  2015.0  Role-Playing
# Star Wars Battlefront (2015)      3757       PC  2015.0       Shooter
# StarCraft II: Legacy of the Void  3890       PC  2015.0      Strategy
# Football Manager 2016             5761       PC  2015.0    Simulation
# Anno 2205                         6745       PC  2015.0      Strategy
# Total War: Attila                 6989       PC  2015.0      Strategy
# Call of Duty: Black Ops 3         7052       PC  2015.0       Shooter
# Tom Clancy's Rainbow Six: Siege   7213       PC  2015.0       Shooter
#
#                                              Publisher  NA_Sales  EU_Sales  \
# Name
# Fallout 4                           Bethesda Softworks      0.50      0.63
# ...
